# %% [markdown]
# # Covid dataa

# %% [markdown]
# Tutkitaan tässä harjoituksessa [Our world in data](https://ourworldindata.org/coronavirus)-sivuston dataa päivittäisistä Covid-tapauksista eri maissa.

# %%
# Tarvittavat paketit

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Luetaan datatiedosto ja katsotaan sisältö

datasetti = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/jhu/biweekly_cases_per_million.csv")
datasetti.head(10)
# Out:
#          date  World  Afghanistan  Africa  Albania  Algeria  Andorra  Angola  \
# 0  2020-01-22    NaN          NaN     NaN      NaN      NaN      NaN     NaN
# 1  2020-01-23    NaN          NaN     NaN      NaN      NaN      NaN     NaN
# 2  2020-01-24    NaN          NaN     NaN      NaN      NaN      NaN     NaN
# 3  2020-01-25    NaN          NaN     NaN      NaN      NaN      NaN     NaN
# 4  2020-01-26    NaN          NaN     NaN      NaN      NaN      NaN     NaN
# 5  2020-01-27    NaN          NaN     NaN      NaN      NaN      NaN     NaN
# 6  2020-01-28    NaN          NaN     NaN      NaN      NaN      NaN     NaN
# 7  2020-01-29    NaN          NaN     NaN      NaN      NaN      NaN     NaN
# 8  2020-01-30    NaN          NaN     NaN      NaN      NaN      NaN     NaN
# 9  2020-01-31    NaN          NaN     NaN      NaN      NaN      NaN     NaN
#
#    Antigua and Barbuda  Argentina  ...  United States  Uruguay  Uzbekistan  \
# 0                  NaN        NaN  ...            NaN      NaN         NaN
# 1                  NaN        NaN  ...            NaN      NaN         NaN
# 2                  NaN        NaN  ...            NaN      NaN         NaN
# 3                  NaN        NaN  ...            NaN      NaN         NaN
# 4                  NaN        NaN  ...            NaN      NaN         NaN
# 5                  NaN        NaN  ...            NaN      NaN         NaN
# 6                  NaN        NaN  ...            NaN      NaN         NaN
# 7                  NaN        NaN  ...            NaN      NaN         NaN
# 8                  NaN        NaN  ...            NaN      NaN         NaN
# 9                  NaN        NaN  ...            NaN      NaN         NaN
#
#    Vanuatu  Vatican  Venezuela  Vietnam  Yemen  Zambia  Zimbabwe
# 0      NaN      NaN        NaN      NaN    NaN     NaN       NaN
# 1      NaN      NaN        NaN      NaN    NaN     NaN       NaN
# 2      NaN      NaN        NaN      NaN    NaN     NaN       NaN
# 3      NaN      NaN        NaN      NaN    NaN     NaN       NaN
# 4      NaN      NaN        NaN      NaN    NaN     NaN       NaN
# 5      NaN      NaN        NaN      NaN    NaN     NaN       NaN
# 6      NaN      NaN        NaN      NaN    NaN     NaN       NaN
# 7      NaN      NaN        NaN      NaN    NaN     NaN       NaN
# 8      NaN      NaN        NaN      NaN    NaN     NaN       NaN
# 9      NaN      NaN        NaN      NaN    NaN     NaN       NaN
#
# [10 rows x 200 columns]

# %%
# Piirretään Suomen koronatapaukset

# Plot-funktiolle voidaan antaa "label"-parametri, jos kuvaajan selite halutaan näkyviin.
plt.plot(datasetti["date"], datasetti["Finland"], label="Finland")

# Näytetään selite
plt.legend() 

# Näytetään kuvaaja
plt.show()

# %% [markdown]
# Huomataan, että x-akseli tulee melko sotkuiseksi jos kaikki päivämäärät piirretään, kuten edellä on tehty. Onglema voidaan korjata käyttämällä Matplotlibin automaattista päivämääränsijoittelutyökalua (AutoDateLocator). Katso alta esimerkki, miten sitä voidaan käyttää.

# %%
# Tuodaan AutoDateLocator-työkalu matplotlibin dates-paketista
from matplotlib.dates import AutoDateLocator

# Luodaan uusi kuvaaja
plt.figure()

# Asetetaan x-akselille automaattinen päivämääräasettelu
xtick_locator = AutoDateLocator()
ax = plt.gca()
ax.xaxis.set_major_locator(xtick_locator)

# Piirretään kuvaaja
plt.plot(datasetti["date"], datasetti["Finland"])

# Käännetään x-akselin otsikoita
plt.xticks(rotation=60)

plt.show()

# %% [markdown]
# ## Tehtävä:
#
# Vertaile useamman eri maan koronatapauksia samassa kuvaajassa ja tee siisti kuvaaja otsikoineen päivineen. Kokeile, saatko päivämäärät siististi x-akselille!

# %%
# Piirretään Suomen koronatapaukset.
# Tarkastellaan lisäksi esim. Ruotsin, Italian, Sveitsin ja Pakistanin koronatartuntojen määriä.

# Plot-funktiolle voidaan antaa "label"-parametri, jos kuvaajan selite halutaan näkyviin.
plt.plot(datasetti["date"], datasetti["Finland"], label="Finland")
plt.plot(datasetti["date"], datasetti["Switzerland"], label="Switzerland")
plt.plot(datasetti["date"], datasetti["Italy"], label="Italy")
plt.plot(datasetti["date"], datasetti["Sweden"], label="Sweden")
plt.plot(datasetti["date"], datasetti["Pakistan"], label="Pakistan")

# Näytetään selite
plt.legend() 

# Näytetään kuvaaja
plt.show()

# %%
# Tuodaan AutoDateLocator-työkalu matplotlibin dates-paketista
from matplotlib.dates import AutoDateLocator

# Luodaan uusi kuvaaja
plt.figure()

# Asetetaan x-akselille automaattinen päivämääräasettelu
xtick_locator = AutoDateLocator()
ax = plt.gca()
ax.xaxis.set_major_locator(xtick_locator)

# Piirretään kuvaaja
plt.plot(datasetti["date"], datasetti["Finland"], label="Finland")
plt.plot(datasetti["date"], datasetti["Switzerland"], label="Switzerland")
plt.plot(datasetti["date"], datasetti["Italy"], label="Italy")
plt.plot(datasetti["date"], datasetti["Sweden"], label="Sweden")
plt.plot(datasetti["date"], datasetti["Pakistan"], label="Pakistan")

# Näytetään selite
plt.legend() 

# Käännetään x-akselin otsikoita
plt.xticks(rotation=60)

#Nimetään kuvaaja.
plt.title('Koronatapaukset maittain 2020-01 - 2021-03')

plt.show()
